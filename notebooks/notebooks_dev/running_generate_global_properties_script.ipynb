# %% [markdown]
# # Generate GLOBAL PROPERTIES

# %%
import datetime

# %%
import s3fs
fs = s3fs.S3FileSystem(endpoint_url="https://s3-west.nrp-nautilus.io")
fs.rm("dbof/native_grid_dbof_training_data/global_properties_20260306_044400/properties.zarr",
      recursive=True)
# Out:
# []

# %% [markdown]
# # Initial set up
# In the future we will want to update this to use docker or conda for end users

# %% [markdown]
# ## These steps help you build the project on a local machine.
# If you are using nrp Jupyterhub, it is recommended you use the next block instead.
#
# #### Build the project
# - ```pip install .```
#
# #### Install aws cli (optional)
# You will want to install this if you want to manually see the data stored in the s3 bucket.
#
# Example for installing on linux :
# - ```sudo curl "https://awscli.amazonaws.com/awscli-exe-linux-x86_64.zip" -o "awscliv2.zip"```
# - ```sudo unzip awscliv2.zip```
# - ```sudo ./aws/install```

# %% [markdown]
# ## Running in NRP Jupyterhub
#
# This is for running this notebook on nrp Jupyterhub.
#
# This block simply builds the project and installs dependencies not already present on nrp jupyterhub.
# You can safely ignore pip warnings
#
# For serious projects, users should use conda or docker but this notebook is meant to be very simple and user friendly.

# %%
#Set True if running on NRP Jupyterhub
RUNNING_ON_NRP = False


if (RUNNING_ON_NRP):
    # %pip install -e ../. --no-deps

    # %pip install xgcm
    # %pip install zarr
    # %pip install boto3
    # %pip install ujson
    # %pip install scikit-fmm
    # %pip install aiobotocore

# NOTE IF on NRP Jupyterhub, you will likely need to restart the kernel after running this block

# %% [markdown]
# ## Set AWS credentials
# If you are accessing or writing data to S3, you must set credentials.
# NOTE : S3 is all that is supported currently.
# This typically corresponds to an NRP S3 bucket.
#
# windows:
#
# - ```$env:AWS_ACCESS_KEY_ID="..."```
# - ```$env:AWS_SECRET_ACCESS_KEY="..."```
#
# unix:
#
# - ```export AWS_ACCESS_KEY_ID=...```
# - ```export AWS_SECRET_ACCESS_KEY=...```

# %% [markdown]
# # Dataset generation config (quick reference)
#
# This job is fully controlled by a YAML config file. The config defines **what time range is scanned**, **how often snapshots are taken**, and **how many spatial patches are sampled per snapshot**.
#
# ### Temporal sampling
# - `data.timestep_hours`
#   Total time window (in hours) to scan starting from `start_record`.
#   Example: `8760` = one LLC model year (336 days).
#
# - `data.sampling_step`
#   Spacing **in hours** between snapshots within the window.
#   Example: `2190` with `timestep_hours=8760` → 4 evenly spaced snapshots.
#
# - `data.start_record`
#   First valid wind/forcing record (default: `1180`). You probably don't want to change this.
#
# Each snapshot corresponds to a **single instantaneous model timestep** (not an average).
#
# ### Spatial sampling
# **not used in the global script; kept for config compatibility**
# - `sampling.sample_points_per_snapshot`
#   Number of cutouts sampled per snapshot.
#
# - `sampling.bias_to_high_gradients`
#   Exponential bias favoring high-gradient regions when sampling.
#
# ### Patch geometry
# **not used in the global script; kept for config compatibility**
# - `output.target_km_res`
#   Physical patch size in km. Default 150.
#
# - `output.down_sample_res`
#   Pixel resolution of the extracted cutouts.
#   Must be small enough to safely resolve `target_km_res` on the LLC grid.
#   Default 64
#
# ### Output / logging
# - `output.bucket`, `output.folder`
#   S3 location for dataset output.
#
# - `run.run_id`
#   Unique identifier for this run (used for logs and output paths).
#   If the run_id you use exists on the write location (s3 bucket), your data will be appended to the existing data from previous run(s).
#
# - `run.log_dir`
#   Local directory where logs are written.
#
# ### Invariants (not configurable)
# Grid topology, model cadence (144 timesteps/hour), and dataset offsets are fixed
# LLC4320 constants and are enforced in code.
#
# ### Examples
# See existing configs in configs/ for examples

# %% [markdown]
# # A note about logs
# The run logs will be stored locally on your machine in the directory you specify.
# - ```log_dir/run_id/```
# However under the current logic, if you attempt to run the script and the specified log output path already exists, the script will fail to run. This is by design. The reasons are as follows.
# - run_id is also used for the zarr dataset path. You likely do not want to send two different runs to the same dataset.
# - You will likely not want to override your previous run logs.
#
# If you want to override this logic, simply delete the existing log output path from your local machine. You can also override the run_id with a cli argument ```--run_id```

# %% [markdown]
# ## Global run
# - 1 year of data
# - 1 time snapshot
# - global per time snapshot
#
# If you are running this on your laptop or pc expect it to take a while.

# %%
run_id = f"global_properties_{datetime.datetime.now(datetime.UTC).strftime('%Y%m%d_%H%M%S')}"
print(f"Your run id is: {run_id}")
print("Make sure and use the same run_id later when accessing your data")
# Out:
# Your run id is: global_properties_20260306_053740
# Make sure and use the same run_id later when accessing your data

# %%
# note: that --run_id can overwrite the config file
# note: All Dask logs are warnings. Don't be alarmed.

# !generate-global-properties-dataset --config ../../configs/global_properties.yaml --run_id {run_id}
# Out:
# 2026-03-05 21:37:44,225 | INFO | Arguments parsed successfully. Logging set up. Running script.
# 2026-03-05 21:37:45,386 | INFO | Dask Client <Client: 'tcp://127.0.0.1:52528' processes=4 threads=16, memory=64.00 GiB>
# 2026-03-05 21:37:45,386 | INFO | Using date-derived iteration list: '11092012-12:00:00' → 1259712
# 2026-03-05 21:37:45,387 | INFO | Processing: [1259712] time snapshots
# 2026-03-05 21:37:45,387 | INFO | Fetching grid file
# 2026-03-05 21:37:50,467 | INFO | Calculating land mask (use_halo=False)
# 2026-03-05 21:38:03,607 | INFO | LLC rectangular output shape: (12960, 17280)
# 2026-03-05 21:38:03,624 | INFO | Found credentials in shared credentials file: ~/.aws/credentials
# 2026-03-05 21:38:04,842 | INFO | Zarr dataset created.
#   0%|                                                     | 0/1 [00:00<?, ?it/s]Opening 13 Kerchunk JSON files...
# Parsing JSON metadata into Python dicts...
# Creating lazy xarray datasets...
# Computing delayed datasets...
# Combining datasets by coordinates...
# Dataset combined successfully.
# 2026-03-05 21:38:08,828 | INFO | Data loaded for iteration: 1259712
# 2026-03-05 21:38:08,828 | INFO | Calculating ice mask
# 2026-03-05 21:39:53,446 | INFO | Masking edges of gradb2 on each face with -999.0 values
# 2026-03-05 21:39:53,689 | INFO | Converting from LLC faces to rectangular lat/lon...
# /Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/xmitgcm/llcreader/llcmodel.py:322: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   data = np.arange(ifac * coords.dims[vname])
# /Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/xmitgcm/llcreader/llcmodel.py:324: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   data = np.arange(jfac * coords.dims[vname])
# 2026-03-05 21:53:26,286 | INFO | Writing snapshot to zarr dataset
#   0%|                                                   | 0/1 [2:20:41<?, ?it/s]
# Traceback (most recent call last):
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/s3fs/core.py", line 114, in _error_wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/aiobotocore/context.py", line 36, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/aiobotocore/client.py", line 424, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.exceptions.ClientError: An error occurred (RequestTimeTooSkewed) when calling the CompleteMultipartUpload operation: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/lahoffma/miniforge3/envs/fronts/bin/generate-global-properties-dataset", line 6, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/Users/lahoffma/projects/Sea-Meets-the-Stars/llc4320-native-grid-preprocessing/src/dbof/cli/generate_properties_global.py", line 353, in main
#     process_time_snapshot(
#   File "/Users/lahoffma/projects/Sea-Meets-the-Stars/llc4320-native-grid-preprocessing/src/dbof/cli/generate_properties_global.py", line 257, in process_time_snapshot
#     zarr_ds.write_snapshot(data, it)
#   File "/Users/lahoffma/projects/Sea-Meets-the-Stars/llc4320-native-grid-preprocessing/src/dbof/dataset_creation/zarr_dataset_global.py", line 161, in write_snapshot
#     self.root["data"][t] = data.astype(np.float32)
#     ~~~~~~~~~~~~~~~~~^^^
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/zarr/core/array.py", line 2975, in __setitem__
#     self.set_orthogonal_selection(pure_selection, value, fields=fields)
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/zarr/core/array.py", line 3458, in set_orthogonal_selection
#     return sync(
#            ^^^^^
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/zarr/core/sync.py", line 159, in sync
#     raise return_result
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/zarr/core/sync.py", line 119, in _runner
#     return await coro
#            ^^^^^^^^^^
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/zarr/core/array.py", line 1736, in _set_selection
#     await self.codec_pipeline.write(
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/zarr/core/codec_pipeline.py", line 488, in write
#     await concurrent_map(
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/zarr/core/common.py", line 116, in concurrent_map
#     return await asyncio.gather(*[asyncio.ensure_future(run(item)) for item in items])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/zarr/core/common.py", line 114, in run
#     return await func(*item)
#            ^^^^^^^^^^^^^^^^^
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/zarr/core/codec_pipeline.py", line 438, in write_batch
#     await concurrent_map(
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/zarr/core/common.py", line 116, in concurrent_map
#     return await asyncio.gather(*[asyncio.ensure_future(run(item)) for item in items])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/zarr/core/common.py", line 114, in run
#     return await func(*item)
#            ^^^^^^^^^^^^^^^^^
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/zarr/core/codec_pipeline.py", line 436, in _write_key
#     await byte_setter.set(chunk_bytes)
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/zarr/storage/_common.py", line 179, in set
#     await self.store.set(self.path, value)
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/zarr/storage/_fsspec.py", line 336, in set
#     await self.fs._pipe_file(path, value.to_bytes())
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/s3fs/core.py", line 1215, in _pipe_file
#     await self._call_s3(
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/s3fs/core.py", line 371, in _call_s3
#     return await _error_wrapper(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lahoffma/miniforge3/envs/fronts/lib/python3.12/site-packages/s3fs/core.py", line 146, in _error_wrapper
#     raise err
# PermissionError: None
# 2026-03-05 23:58:46,355 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:52545' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 1, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 1, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 4, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 0, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 1, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 2, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 4, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 3, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 5, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 3, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 0, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 5, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 1, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 3, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 2, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 1, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 1, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 0, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 5, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 0, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 3, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 4, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 4, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 2, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 4, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 0, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 0, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 0, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 1, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 1, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 1, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 3, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 1, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 2, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 0, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 0, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 4, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 3, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 0, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 3, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 2, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 4, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 2, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 2, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 3, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 5, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 1, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 3, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 2, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 5, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 10, 4, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 0, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 1, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 5, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 4, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 3, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 2, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 2, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 4, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 3, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 5, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 3, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 3, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 0, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 1, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 1, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 0, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 5, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 0, 5), ('t ...
# 2026-03-05 23:58:46,477 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:52543' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 3, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 2, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 0, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 0, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 0, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 0, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 2, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 4, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 2, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 2, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 4, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 1, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 4, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 3, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 2, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 5, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 5, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 1, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 5, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 4, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 3, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 0, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 5, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 1, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 2, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 0, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 4, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 2, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 1, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 3, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 4, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 4, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 3, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 1, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 10, 5, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 5, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 1, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 0, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 3, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 4, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 3, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 1, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 1, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 10, 2, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 2, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 1, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 5, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 2, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 4, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 4, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 10, 0, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 5, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 0, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 0, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 1, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 2, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 0, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 0, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 1, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 4, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 4, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 5, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 10, 1, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 2, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 10, 3, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 2, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 1, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 5, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 0, 3), (' ...
# 2026-03-05 23:58:46,493 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:52552' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 4, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 2, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 5, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 5, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 0, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 2, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 10, 3, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 1, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 1, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 3, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 2, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 3, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 5, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 1, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 10, 1, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 2, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 5, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 2, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 4, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 5, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 4, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 5, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 2, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 3, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 3, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 4, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 5, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 0, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 5, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 2, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 5, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 10, 4, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 0, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 1, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 1, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 3, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 5, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 3, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 2, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 5, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 4, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 1, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 0, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 1, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 0, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 3, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 5, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 2, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 3, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 4, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 1, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 5, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 4, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 3, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 5, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 3, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 2, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 4, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 3, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 1, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 2, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 3, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 0, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 0, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 5, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 1, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 0, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 1, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 4, 4), ( ...
# 2026-03-05 23:58:46,511 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:52544' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 2, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 2, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 5, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 5, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 10, 5, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 1, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 2, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 4, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 0, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 0, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 5, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 1, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 4, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 4, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 3, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 1, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 5, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 2, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 4, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 5, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 0, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 1, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 5, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 3, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 0, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 3, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 10, 4, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 12, 4, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 2, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 1, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 10, 1, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 2, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 5, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 4, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 5, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 3, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 5, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 2, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 4, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 3, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 0, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 5, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 0, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 4, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 0, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 10, 0, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 8, 3, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 2, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 0, 4, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 5, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 2, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 5, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 2, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 1, 3), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 2, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 5, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 0, 5), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 0, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 4, 1, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 11, 3, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 1, 3, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 2, 0, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 2, 1), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 9, 3, 4), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 5, 5, 0), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 3, 1, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 7, 4, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 6, 0, 2), ('truediv-4aed52fdf29ae56816a538bfd237ce5b', 10, 4, 2) ...

# %%
# aws cli arguments for listing or deleting data in the s3 bucket

# aws --endpoint https://s3-west.nrp-nautilus.io s3 ls s3://llc/native_grid_dbof_training_data/script_test_00/ --human-readable
#
# aws --endpoint https://s3-west.nrp-nautilus.io s3 rm s3://llc/native_grid_dbof_training_data/script_test_00/ --recursive --dryrun
