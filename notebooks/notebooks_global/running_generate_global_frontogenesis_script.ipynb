# %% [markdown]
# # Generate GLOBAL FRONTOGENESIS

# %%
import datetime

# %% [markdown]
# # Initial set up
# In the future we will want to update this to use docker or conda for end users

# %% [markdown]
# ## These steps help you build the project on a local machine.
# If you are using nrp Jupyterhub, it is recommended you use the next block instead.
#
# #### Build the project
# - ```pip install .```
#
# #### Install aws cli (optional)
# You will want to install this if you want to manually see the data stored in the s3 bucket.
#
# Example for installing on linux :
# - ```sudo curl "https://awscli.amazonaws.com/awscli-exe-linux-x86_64.zip" -o "awscliv2.zip"```
# - ```sudo unzip awscliv2.zip```
# - ```sudo ./aws/install```

# %% [markdown]
# ## Running in NRP Jupyterhub
#
# This is for running this notebook on nrp Jupyterhub.
#
# This block simply builds the project and installs dependencies not already present on nrp jupyterhub.
# You can safely ignore pip warnings
#
# For serious projects, users should use conda or docker but this notebook is meant to be very simple and user friendly.

# %%
#Set True if running on NRP Jupyterhub
RUNNING_ON_NRP = False


if (RUNNING_ON_NRP):
    # %pip install -e ../. --no-deps

    # %pip install xgcm
    # %pip install zarr
    # %pip install boto3
    # %pip install ujson
    # %pip install scikit-fmm
    # %pip install aiobotocore

# NOTE IF on NRP Jupyterhub, you will likely need to restart the kernel after running this block

# %% [markdown]
# ## Set AWS credentials
# If you are accessing or writing data to S3, you must set credentials.
# NOTE : S3 is all that is supported currently.
# This typically corresponds to an NRP S3 bucket.
#
# windows:
#
# - ```$env:AWS_ACCESS_KEY_ID="..."```
# - ```$env:AWS_SECRET_ACCESS_KEY="..."```
#
# unix:
#
# - ```export AWS_ACCESS_KEY_ID=...```
# - ```export AWS_SECRET_ACCESS_KEY=...```

# %% [markdown]
# # Dataset generation config (quick reference)
#
# This job is fully controlled by a YAML config file. The config defines **what time range is scanned**, **how often snapshots are taken**, and **how many spatial patches are sampled per snapshot**.
#
# ### Temporal sampling
# - `data.timestep_hours`
#   Total time window (in hours) to scan starting from `start_record`.
#   Example: `8760` = one LLC model year (336 days).
#
# - `data.sampling_step`
#   Spacing **in hours** between snapshots within the window.
#   Example: `2190` with `timestep_hours=8760` → 4 evenly spaced snapshots.
#
# - `data.start_record`
#   First valid wind/forcing record (default: `1180`). You probably don't want to change this.
#
# Each snapshot corresponds to a **single instantaneous model timestep** (not an average).
#
# ### Spatial sampling
# **not used in the global script; kept for config compatibility**
# - `sampling.sample_points_per_snapshot`
#   Number of cutouts sampled per snapshot.
#
# - `sampling.bias_to_high_gradients`
#   Exponential bias favoring high-gradient regions when sampling.
#
# ### Patch geometry
# **not used in the global script; kept for config compatibility**
# - `output.target_km_res`
#   Physical patch size in km. Default 150.
#
# - `output.down_sample_res`
#   Pixel resolution of the extracted cutouts.
#   Must be small enough to safely resolve `target_km_res` on the LLC grid.
#   Default 64
#
# ### Output / logging
# - `output.bucket`, `output.folder`
#   S3 location for dataset output.
#
# - `run.run_id`
#   Unique identifier for this run (used for logs and output paths).
#   If the run_id you use exists on the write location (s3 bucket), your data will be appended to the existing data from previous run(s).
#
# - `run.log_dir`
#   Local directory where logs are written.
#
# ### Invariants (not configurable)
# Grid topology, model cadence (144 timesteps/hour), and dataset offsets are fixed
# LLC4320 constants and are enforced in code.
#
# ### Examples
# See existing configs in configs/ for examples

# %% [markdown]
# # A note about logs
# The run logs will be stored locally on your machine in the directory you specify.
# - ```log_dir/run_id/```
# However under the current logic, if you attempt to run the script and the specified log output path already exists, the script will fail to run. This is by design. The reasons are as follows.
# - run_id is also used for the zarr dataset path. You likely do not want to send two different runs to the same dataset.
# - You will likely not want to override your previous run logs.
#
# If you want to override this logic, simply delete the existing log output path from your local machine. You can also override the run_id with a cli argument ```--run_id```

# %% [markdown]
# ## Global run
# - 1 year of data
# - 1 time snapshot
# - global per time snapshot
#
# If you are running this on your laptop or pc expect it to take a while.

# %%
run_id = f"frontogenesis_{datetime.datetime.now(datetime.UTC).strftime('%Y%m%d_%H%M%S')}"
print(f"Your run id is: {run_id}")
print("Make sure and use the same run_id later when accessing your data")
# Out:
# Your run id is: frontogenesis_20260307_033945
# Make sure and use the same run_id later when accessing your data

# %%
# note: that --run_id can overwrite the config file
# note: All Dask logs are warnings. Don't be alarmed.

# !generate-global-frontogenesis-dataset --config ../../configs/frontogenesis_global.yaml --run_id {run_id}
# Out:
# 2026-03-06 19:39:55,189 | INFO | Arguments parsed successfully. Logging set up. Running script.
# 2026-03-06 19:40:02,380 | INFO | Dask Client <Client: 'tcp://127.0.0.1:41045' processes=6 threads=24, memory=755.17 GiB>
# 2026-03-06 19:40:02,381 | INFO | Using date-derived iteration list: '2012-11-09 12:00:00' → 1463616
# 2026-03-06 19:40:02,381 | INFO | Processing: [1463616] time snapshots
# 2026-03-06 19:40:02,382 | INFO | Fetching grid file
# 2026-03-06 19:40:07,862 | INFO | Calculating land mask (use_halo=False)
# 2026-03-06 19:40:11,880 | INFO | LLC rectangular output shape: (12960, 17280)
# 2026-03-06 19:40:11,896 | INFO | Found credentials in shared credentials file: ~/.aws/credentials
# 2026-03-06 19:40:13,283 | INFO | Zarr dataset created.
#   0%|                                                     | 0/1 [00:00<?, ?it/s]Opening 13 Kerchunk JSON files...
# Parsing JSON metadata into Python dicts...
# Creating lazy xarray datasets...
# Computing delayed datasets...
# Combining datasets by coordinates...
# Dataset combined successfully.
# 2026-03-06 19:40:17,181 | INFO | Data loaded for iteration: 1463616
# 2026-03-06 19:41:00,545 | INFO | Converting from LLC faces to rectangular lat/lon...
# /home/lhoffma2/miniforge3/envs/llcngp/lib/python3.12/site-packages/xmitgcm/llcreader/llcmodel.py:322: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   data = np.arange(ifac * coords.dims[vname])
# /home/lhoffma2/miniforge3/envs/llcngp/lib/python3.12/site-packages/xmitgcm/llcreader/llcmodel.py:324: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   data = np.arange(jfac * coords.dims[vname])
# /home/lhoffma2/miniforge3/envs/llcngp/lib/python3.12/site-packages/distributed/client.py:3370: UserWarning: Sending large graph of size 10.67 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /home/lhoffma2/miniforge3/envs/llcngp/lib/python3.12/site-packages/distributed/client.py:3370: UserWarning: Sending large graph of size 11.31 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /home/lhoffma2/miniforge3/envs/llcngp/lib/python3.12/site-packages/distributed/client.py:3370: UserWarning: Sending large graph of size 16.58 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# 2026-03-06 19:44:33,403 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-415b3fab7dd2ee644c66af269772f390', 5, 6, 5) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-415b3fab7dd2ee644c66af269772f390', 5, 6, 5)->('concatenate-transpose-getitem-415b3fab7dd2ee644c66af269772f390', 5, 6, 5))
# new run_spec: Alias(('getitem-415b3fab7dd2ee644c66af269772f390', 5, 6, 5)->('concatenate-transpose-truediv-getitem-415b3fab7dd2ee644c66af269772f390', 5, 6, 5))
# old dependencies: {('concatenate-transpose-getitem-415b3fab7dd2ee644c66af269772f390', 5, 6, 5)}
# new dependencies: frozenset({('concatenate-transpose-truediv-getitem-415b3fab7dd2ee644c66af269772f390', 5, 6, 5)})
#
# 2026-03-06 19:44:33,403 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('overlap-3f1da21072137eb3790a9e18c23df96d', 6, 5, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('overlap-3f1da21072137eb3790a9e18c23df96d', 6, 5, 0)->('getitem-overlap-3f1da21072137eb3790a9e18c23df96d', 6, 5, 0))
# new run_spec: Alias(('overlap-3f1da21072137eb3790a9e18c23df96d', 6, 5, 0)->('getitem-rechunk-merge-transpose-overlap-3f1da21072137eb3790a9e18c23df96d', 6, 5, 0))
# old dependencies: {('getitem-overlap-3f1da21072137eb3790a9e18c23df96d', 6, 5, 0)}
# new dependencies: frozenset({('getitem-rechunk-merge-transpose-overlap-3f1da21072137eb3790a9e18c23df96d', 6, 5, 0)})
#
# 2026-03-06 19:44:33,403 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-6944b6f8bf5b27bed0d413e09e4634c0', 6, 1, 5) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-6944b6f8bf5b27bed0d413e09e4634c0', 6, 1, 5) _execute_subgraph(...)>
# new run_spec: Alias(('getitem-6944b6f8bf5b27bed0d413e09e4634c0', 6, 1, 5)->('concatenate-transpose-getitem-6944b6f8bf5b27bed0d413e09e4634c0', 6, 1, 5))
# old dependencies: {('concatenate-8b6471797e968b68f968d03f3e9bf20c', 6, 1, 6)}
# new dependencies: frozenset({('concatenate-transpose-getitem-6944b6f8bf5b27bed0d413e09e4634c0', 6, 1, 5)})
#
# 2026-03-06 19:44:33,403 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-11bf5433a7e168de07414082e3350e9e', 6, 3, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-11bf5433a7e168de07414082e3350e9e', 6, 3, 0)->('getitem-rechunk-merge-11bf5433a7e168de07414082e3350e9e', 6, 3, 0))
# new run_spec: Alias(('rechunk-merge-11bf5433a7e168de07414082e3350e9e', 6, 3, 0)->('concatenate-getitem-open_dataset-Eta-transpose-rechunk-merge-11bf5433a7e168de07414082e3350e9e', 6, 3, 0))
# old dependencies: {('getitem-rechunk-merge-11bf5433a7e168de07414082e3350e9e', 6, 3, 0)}
# new dependencies: frozenset({('concatenate-getitem-open_dataset-Eta-transpose-rechunk-merge-11bf5433a7e168de07414082e3350e9e', 6, 3, 0)})
#
# 2026-03-06 19:44:33,403 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-3920dc50c7282b268dc3a3a765349d54', 0, 6, 3) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-3920dc50c7282b268dc3a3a765349d54', 0, 6, 3)->('concatenate-transpose-getitem-3920dc50c7282b268dc3a3a765349d54', 0, 6, 3))
# new run_spec: Alias(('getitem-3920dc50c7282b268dc3a3a765349d54', 0, 6, 3)->('concatenate-open_dataset-Eta-transpose-getitem-3920dc50c7282b268dc3a3a765349d54', 0, 6, 3))
# old dependencies: {('concatenate-transpose-getitem-3920dc50c7282b268dc3a3a765349d54', 0, 6, 3)}
# new dependencies: frozenset({('concatenate-open_dataset-Eta-transpose-getitem-3920dc50c7282b268dc3a3a765349d54', 0, 6, 3)})
#
# 2026-03-06 19:44:33,403 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-3629e0241964840e94198d34d0e42e88', 12, 0, 6) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-3629e0241964840e94198d34d0e42e88', 12, 0, 6)->('concatenate-transpose-getitem-3629e0241964840e94198d34d0e42e88', 12, 0, 6))
# new run_spec: Alias(('getitem-3629e0241964840e94198d34d0e42e88', 12, 0, 6)->('broadcast_to-concatenate-transpose-getitem-3629e0241964840e94198d34d0e42e88', 12, 0, 6))
# old dependencies: {('concatenate-transpose-getitem-3629e0241964840e94198d34d0e42e88', 12, 0, 6)}
# new dependencies: frozenset({('broadcast_to-concatenate-transpose-getitem-3629e0241964840e94198d34d0e42e88', 12, 0, 6)})
#
# 2026-03-06 19:44:33,404 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-7523f81db37753d134cbbfa84295842b', 10, 1, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-7523f81db37753d134cbbfa84295842b', 10, 1, 0)->('concatenate-transpose-getitem-7523f81db37753d134cbbfa84295842b', 10, 1, 0))
# new run_spec: Alias(('getitem-7523f81db37753d134cbbfa84295842b', 10, 1, 0)->('concatenate-open_dataset-Eta-transpose-getitem-7523f81db37753d134cbbfa84295842b', 10, 1, 0))
# old dependencies: {('concatenate-transpose-getitem-7523f81db37753d134cbbfa84295842b', 10, 1, 0)}
# new dependencies: frozenset({('concatenate-open_dataset-Eta-transpose-getitem-7523f81db37753d134cbbfa84295842b', 10, 1, 0)})
#
# 2026-03-06 19:44:33,406 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-a361d7c6eb19549be777d762c7f807d6', 10, 1, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-a361d7c6eb19549be777d762c7f807d6', 10, 1, 0)->('concatenate-getitem-transpose-rechunk-merge-a361d7c6eb19549be777d762c7f807d6', 10, 1, 0))
# new run_spec: Alias(('rechunk-merge-a361d7c6eb19549be777d762c7f807d6', 10, 1, 0)->('concatenate-getitem-transpose-truediv-rechunk-merge-a361d7c6eb19549be777d762c7f807d6', 10, 1, 0))
# old dependencies: {('concatenate-getitem-transpose-rechunk-merge-a361d7c6eb19549be777d762c7f807d6', 10, 1, 0)}
# new dependencies: frozenset({('concatenate-getitem-transpose-truediv-rechunk-merge-a361d7c6eb19549be777d762c7f807d6', 10, 1, 0)})
#
# 2026-03-06 19:44:33,406 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-3f1da21072137eb3790a9e18c23df96d', 6, 0, 5) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-3f1da21072137eb3790a9e18c23df96d', 6, 0, 5)->('rechunk-merge-transpose-getitem-3f1da21072137eb3790a9e18c23df96d', 6, 0, 5))
# new run_spec: Alias(('getitem-3f1da21072137eb3790a9e18c23df96d', 6, 0, 5)->('concatenate-rechunk-merge-transpose-getitem-3f1da21072137eb3790a9e18c23df96d', 6, 0, 5))
# old dependencies: {('rechunk-merge-transpose-getitem-3f1da21072137eb3790a9e18c23df96d', 6, 0, 5)}
# new dependencies: frozenset({('concatenate-rechunk-merge-transpose-getitem-3f1da21072137eb3790a9e18c23df96d', 6, 0, 5)})
#
# 2026-03-06 19:44:33,414 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-eb5ad6008dc42a6ea7d0c4badf19125c', 7, 4, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-eb5ad6008dc42a6ea7d0c4badf19125c', 7, 4, 0)->('concatenate-rechunk-merge-transpose-getitem-eb5ad6008dc42a6ea7d0c4badf19125c', 7, 4, 0))
# new run_spec: Alias(('getitem-eb5ad6008dc42a6ea7d0c4badf19125c', 7, 4, 0)->('concatenate-rechunk-merge-transpose-truediv-getitem-eb5ad6008dc42a6ea7d0c4badf19125c', 7, 4, 0))
# old dependencies: {('concatenate-rechunk-merge-transpose-getitem-eb5ad6008dc42a6ea7d0c4badf19125c', 7, 4, 0)}
# new dependencies: frozenset({('concatenate-rechunk-merge-transpose-truediv-getitem-eb5ad6008dc42a6ea7d0c4badf19125c', 7, 4, 0)})
#
# 2026-03-06 19:44:58,429 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-6944b6f8bf5b27bed0d413e09e4634c0', 0, 0, 4) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-6944b6f8bf5b27bed0d413e09e4634c0', 0, 0, 4)->('concatenate-getitem-6944b6f8bf5b27bed0d413e09e4634c0', 0, 0, 4))
# new run_spec: Alias(('getitem-6944b6f8bf5b27bed0d413e09e4634c0', 0, 0, 4)->('broadcast_to-concatenate-getitem-6944b6f8bf5b27bed0d413e09e4634c0', 0, 0, 4))
# old dependencies: {('concatenate-getitem-6944b6f8bf5b27bed0d413e09e4634c0', 0, 0, 4)}
# new dependencies: frozenset({('broadcast_to-concatenate-getitem-6944b6f8bf5b27bed0d413e09e4634c0', 0, 0, 4)})
#
# 2026-03-06 19:44:58,430 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-3629e0241964840e94198d34d0e42e88', 12, 3, 6) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-3629e0241964840e94198d34d0e42e88', 12, 3, 6)->('concatenate-transpose-getitem-3629e0241964840e94198d34d0e42e88', 12, 3, 6))
# new run_spec: Alias(('getitem-3629e0241964840e94198d34d0e42e88', 12, 3, 6)->('broadcast_to-concatenate-transpose-getitem-3629e0241964840e94198d34d0e42e88', 12, 3, 6))
# old dependencies: {('concatenate-transpose-getitem-3629e0241964840e94198d34d0e42e88', 12, 3, 6)}
# new dependencies: frozenset({('broadcast_to-concatenate-transpose-getitem-3629e0241964840e94198d34d0e42e88', 12, 3, 6)})
#
# 2026-03-06 19:44:58,431 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-7523f81db37753d134cbbfa84295842b', 10, 2, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-7523f81db37753d134cbbfa84295842b', 10, 2, 0)->('concatenate-transpose-getitem-7523f81db37753d134cbbfa84295842b', 10, 2, 0))
# new run_spec: Alias(('getitem-7523f81db37753d134cbbfa84295842b', 10, 2, 0)->('concatenate-open_dataset-Eta-transpose-getitem-7523f81db37753d134cbbfa84295842b', 10, 2, 0))
# old dependencies: {('concatenate-transpose-getitem-7523f81db37753d134cbbfa84295842b', 10, 2, 0)}
# new dependencies: frozenset({('concatenate-open_dataset-Eta-transpose-getitem-7523f81db37753d134cbbfa84295842b', 10, 2, 0)})
#
# 2026-03-06 19:44:58,431 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-415b3fab7dd2ee644c66af269772f390', 5, 6, 5) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-415b3fab7dd2ee644c66af269772f390', 5, 6, 5)->('concatenate-transpose-getitem-415b3fab7dd2ee644c66af269772f390', 5, 6, 5))
# new run_spec: Alias(('getitem-415b3fab7dd2ee644c66af269772f390', 5, 6, 5)->('concatenate-transpose-truediv-getitem-415b3fab7dd2ee644c66af269772f390', 5, 6, 5))
# old dependencies: {('concatenate-transpose-getitem-415b3fab7dd2ee644c66af269772f390', 5, 6, 5)}
# new dependencies: frozenset({('concatenate-transpose-truediv-getitem-415b3fab7dd2ee644c66af269772f390', 5, 6, 5)})
#
# 2026-03-06 19:44:58,431 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('overlap-3f1da21072137eb3790a9e18c23df96d', 6, 5, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('overlap-3f1da21072137eb3790a9e18c23df96d', 6, 5, 0)->('getitem-overlap-3f1da21072137eb3790a9e18c23df96d', 6, 5, 0))
# new run_spec: Alias(('overlap-3f1da21072137eb3790a9e18c23df96d', 6, 5, 0)->('getitem-rechunk-merge-transpose-overlap-3f1da21072137eb3790a9e18c23df96d', 6, 5, 0))
# old dependencies: {('getitem-overlap-3f1da21072137eb3790a9e18c23df96d', 6, 5, 0)}
# new dependencies: frozenset({('getitem-rechunk-merge-transpose-overlap-3f1da21072137eb3790a9e18c23df96d', 6, 5, 0)})
#
# 2026-03-06 19:44:58,434 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-3920dc50c7282b268dc3a3a765349d54', 0, 6, 5) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-3920dc50c7282b268dc3a3a765349d54', 0, 6, 5)->('concatenate-transpose-getitem-3920dc50c7282b268dc3a3a765349d54', 0, 6, 5))
# new run_spec: Alias(('getitem-3920dc50c7282b268dc3a3a765349d54', 0, 6, 5)->('concatenate-open_dataset-Eta-transpose-getitem-3920dc50c7282b268dc3a3a765349d54', 0, 6, 5))
# old dependencies: {('concatenate-transpose-getitem-3920dc50c7282b268dc3a3a765349d54', 0, 6, 5)}
# new dependencies: frozenset({('concatenate-open_dataset-Eta-transpose-getitem-3920dc50c7282b268dc3a3a765349d54', 0, 6, 5)})
#
# 2026-03-06 19:44:58,437 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-11bf5433a7e168de07414082e3350e9e', 6, 2, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-11bf5433a7e168de07414082e3350e9e', 6, 2, 0)->('getitem-rechunk-merge-11bf5433a7e168de07414082e3350e9e', 6, 2, 0))
# new run_spec: Alias(('rechunk-merge-11bf5433a7e168de07414082e3350e9e', 6, 2, 0)->('concatenate-getitem-open_dataset-Eta-transpose-rechunk-merge-11bf5433a7e168de07414082e3350e9e', 6, 2, 0))
# old dependencies: {('getitem-rechunk-merge-11bf5433a7e168de07414082e3350e9e', 6, 2, 0)}
# new dependencies: frozenset({('concatenate-getitem-open_dataset-Eta-transpose-rechunk-merge-11bf5433a7e168de07414082e3350e9e', 6, 2, 0)})
#
# 2026-03-06 19:44:58,439 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-a361d7c6eb19549be777d762c7f807d6', 10, 2, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-a361d7c6eb19549be777d762c7f807d6', 10, 2, 0)->('concatenate-getitem-transpose-rechunk-merge-a361d7c6eb19549be777d762c7f807d6', 10, 2, 0))
# new run_spec: Alias(('rechunk-merge-a361d7c6eb19549be777d762c7f807d6', 10, 2, 0)->('concatenate-getitem-transpose-truediv-rechunk-merge-a361d7c6eb19549be777d762c7f807d6', 10, 2, 0))
# old dependencies: {('concatenate-getitem-transpose-rechunk-merge-a361d7c6eb19549be777d762c7f807d6', 10, 2, 0)}
# new dependencies: frozenset({('concatenate-getitem-transpose-truediv-rechunk-merge-a361d7c6eb19549be777d762c7f807d6', 10, 2, 0)})
#
# 2026-03-06 19:44:58,441 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-eb5ad6008dc42a6ea7d0c4badf19125c', 7, 5, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-eb5ad6008dc42a6ea7d0c4badf19125c', 7, 5, 0)->('concatenate-rechunk-merge-transpose-getitem-eb5ad6008dc42a6ea7d0c4badf19125c', 7, 5, 0))
# new run_spec: Alias(('getitem-eb5ad6008dc42a6ea7d0c4badf19125c', 7, 5, 0)->('concatenate-rechunk-merge-transpose-truediv-getitem-eb5ad6008dc42a6ea7d0c4badf19125c', 7, 5, 0))
# old dependencies: {('concatenate-rechunk-merge-transpose-getitem-eb5ad6008dc42a6ea7d0c4badf19125c', 7, 5, 0)}
# new dependencies: frozenset({('concatenate-rechunk-merge-transpose-truediv-getitem-eb5ad6008dc42a6ea7d0c4badf19125c', 7, 5, 0)})
#
# 2026-03-06 19:44:58,447 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-3f1da21072137eb3790a9e18c23df96d', 6, 0, 5) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('getitem-3f1da21072137eb3790a9e18c23df96d', 6, 0, 5)->('rechunk-merge-transpose-getitem-3f1da21072137eb3790a9e18c23df96d', 6, 0, 5))
# new run_spec: Alias(('getitem-3f1da21072137eb3790a9e18c23df96d', 6, 0, 5)->('concatenate-rechunk-merge-transpose-getitem-3f1da21072137eb3790a9e18c23df96d', 6, 0, 5))
# old dependencies: {('rechunk-merge-transpose-getitem-3f1da21072137eb3790a9e18c23df96d', 6, 0, 5)}
# new dependencies: frozenset({('concatenate-rechunk-merge-transpose-getitem-3f1da21072137eb3790a9e18c23df96d', 6, 0, 5)})
#
# 2026-03-06 19:45:28,660 | INFO | Writing snapshot to zarr dataset
# 100%|████████████████████████████████████████████| 1/1 [09:02<00:00, 542.48s/it]

# %%
# aws cli arguments for listing or deleting data in the s3 bucket

# aws --endpoint https://s3-west.nrp-nautilus.io s3 ls s3://llc/native_grid_dbof_training_data/script_test_00/ --human-readable
#
# aws --endpoint https://s3-west.nrp-nautilus.io s3 rm s3://llc/native_grid_dbof_training_data/script_test_00/ --recursive --dryrun

# %% [markdown]
# # Run the next block if you want to delete a run from S3
#
# Don't forget to update the run name (i.e. frontogenesis_XXXXXXXX_XXXXXX)

# %%
#import s3fs
#fs = s3fs.S3FileSystem(endpoint_url="https://s3-west.nrp-nautilus.io")
#fs.rm("dbof/native_grid_dbof_training_data/frontogenesis_20260306_000000/frontogenesis.zarr",
#      recursive=True)
